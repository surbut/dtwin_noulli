# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('default')
sns.set_palette("husl")

from differential_response_analysis import DifferentialResponseAnalyzer

# Load data
thetas = np.load('/Users/sarahurbut/dtwin_noulli/data/thetas.npy')
processed_ids = np.load('/Users/sarahurbut/dtwin_noulli/data/processed_ids.npy')
prs_matrix = np.load('/Users/sarahurbut/dtwin_noulli/data/prs_matrix.npy')
prs_labels = np.load('/Users/sarahurbut/dtwin_noulli/data/prs_labels.npy')
disease_names = np.load('/Users/sarahurbut/dtwin_noulli/data/disease_names.npy')
covariate_dicts = np.load('/Users/sarahurbut/dtwin_noulli/data/covariate_dicts.npy')
